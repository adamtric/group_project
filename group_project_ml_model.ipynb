# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import hvplot.pandas
import plotly.express as px
import sqlalchemy
from sqlalchemy import create_engine, func
from config import db_password

# %%
# Create engine and import SQL database

db_password = 'tricarico12'

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/group_project"

engine = create_engine(db_string) 

df = pd.read_sql('final_database', con = engine)

df
# Out:
#       index  Year Ticker                            Company        Sector  \
# 0         0  2021    WMT                       Walmart Inc.  Retail Trade
# 1         1  2020    WMT                       Walmart Inc.  Retail Trade
# 2         2  2019    WMT                       Walmart Inc.  Retail Trade
# 3         3  2018    WMT                       Walmart Inc.  Retail Trade
# 4         4  2021   AMZN                   Amazon.com, Inc.  Retail Trade
# ...     ...   ...    ...                                ...           ...
# 1927   1927  2018    HST                        Host Hotels       Finance
# 1928   1928  2021    PNW  Pinnacle West Capital Corporation     Utilities
# 1929   1929  2020    PNW  Pinnacle West Capital Corporation     Utilities
# 1930   1930  2019    PNW  Pinnacle West Capital Corporation     Utilities
# 1931   1931  2018    PNW  Pinnacle West Capital Corporation     Utilities
#
#       numEmployees     netIncome  netIncome_per_emp   grossProfit  \
# 0        2300000.0  1.367300e+10       5.944783e+03  1.437540e+11
# 1        2070000.0  1.351000e+10       6.526570e+03  1.388360e+11
# 2        1863000.0  1.488100e+10       7.987654e+03  1.293590e+11
# 3        1676700.0  6.670000e+09       3.978052e+03  1.291040e+11
# 4        1298000.0  3.336400e+10       2.570416e+04  1.974780e+11
# ...            ...           ...                ...           ...
# 1927         119.0  1.087000e+09       9.147753e+06  1.601000e+09
# 1928          88.0  6.187200e+08       7.030909e+06  1.697217e+09
# 1929          79.0  5.505590e+08       6.951503e+06  1.634653e+09
# 1930          71.0  5.383200e+08       7.552189e+06  1.487356e+09
# 1931          64.0  5.110470e+08       7.966190e+06  1.578387e+09
#
#       grossProfit_per_emp  operatingIncome  operatingIncome_per_emp  \
# 0            6.250174e+04     2.594200e+10             1.127913e+04
# 1            6.707053e+04     2.694800e+10             1.301836e+04
# 2            6.943586e+04     2.146800e+10             1.152335e+04
# 3            7.699887e+04     2.195700e+10             1.309537e+04
# 4            1.521402e+05     2.487900e+10             1.916718e+04
# ...                   ...              ...                      ...
# 1927         1.347337e+07     8.130000e+08             6.841879e+06
# 1928         1.928656e+07     9.178510e+08             1.043012e+07
# 1929         2.063956e+07     8.444930e+08             1.066279e+07
# 1930         2.086639e+07     6.949490e+08             9.749565e+06
# 1931         2.460386e+07     8.234780e+08             1.283636e+07
#
#       totalRevenue  totalRevenue_per_emp  totalOperatingExpenses  \
# 0     5.727540e+11          2.490235e+05            5.468120e+11
# 1     5.591510e+11          2.701213e+05            5.322030e+11
# 2     5.239640e+11          2.812475e+05            5.024960e+11
# 3     5.144050e+11          3.067961e+05            4.924480e+11
# 4     4.698220e+11          3.619584e+05            4.449430e+11
# ...            ...                   ...                     ...
# 1927  5.554000e+09          4.674022e+07            4.741000e+09
# 1928  3.803835e+09          4.322540e+07            2.885984e+09
# 1929  3.586982e+09          4.529018e+07            2.742489e+09
# 1930  3.471209e+09          4.869822e+07            2.776260e+09
# 1931  3.691247e+09          5.753908e+07            2.867769e+09
#
#       totalOperatingExpenses_per_emp  mostly_remote
# 0                       2.377443e+05              0
# 1                       2.571029e+05              1
# 2                       2.697241e+05              0
# 3                       2.937007e+05              0
# 4                       3.427912e+05              0
# ...                              ...            ...
# 1927                    3.989834e+07              0
# 1928                    3.279527e+07              0
# 1929                    3.462739e+07              0
# 1930                    3.894865e+07              0
# 1931                    4.470272e+07              0
#
# [1932 rows x 17 columns]

# %%
# Create X

X =  df.drop(columns = ["Year", "Ticker", "Company", "Sector", "netIncome", "grossProfit", "operatingIncome", "totalRevenue", "totalOperatingExpenses", "mostly_remote"])

print(X.shape)
# Out:
# (1932, 7)

# %%
# Standardize the data

X_scaled = StandardScaler().fit_transform(X)

X_scaled[:5]
# Out:
# C:\Users\trica\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name']. An error will be raised in 1.2.
#
# C:\Users\trica\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name']. An error will be raised in 1.2.
# array([[-1.73115453, 18.4935165 , -0.25601673, -0.34736478, -0.30714274,
#         -0.29646192, -0.27538494],
#        [-1.72936152, 16.60433349, -0.25508002, -0.34391264, -0.30470864,
#         -0.28947964, -0.26750265],
#        [-1.72756851, 14.90406879, -0.2527276 , -0.34212542, -0.30680094,
#         -0.28579744, -0.26236363],
#        [-1.72577549, 13.37383055, -0.25918326, -0.33641088, -0.30460086,
#         -0.27734215, -0.25260097],
#        [-1.72398248, 10.26324966, -0.22420316, -0.27963475, -0.29610319,
#         -0.25908626, -0.23261261]])

# %%
# Creating PCA Model

pca = PCA(n_components = 3, random_state = 0)

X_pca = pca.fit_transform(X_scaled)

X_pca
# Out:
# array([[-2.38496585, 14.66647212, 11.00647486],
#        [-2.23024044, 13.27174762,  9.75918391],
#        [-2.09484893, 12.01569592,  8.63723598],
#        ...,
#        [30.7220664 ,  4.07435269, -1.68023886],
#        [31.89332488,  4.3447856 , -2.11385871],
#        [37.69712754,  5.3640739 , -2.5843253 ]])

# %%
# Creating PCA Dataframe

pca_df = pd.DataFrame(data = X_pca, index = X.index, columns = ["PC1", "PC2", "PC3"])

print(pca_df.shape)

pca_df.head(10)
# Out:
# (1932, 3)
#         PC1        PC2        PC3
# 0 -2.384966  14.666472  11.006475
# 1 -2.230240  13.271748   9.759184
# 2 -2.094849  12.015696   8.637236
# 3 -1.968273  10.885896   7.626092
# 4 -1.668594   8.597475   5.572142
# 5 -1.608834   7.804746   4.872481
# 6 -1.570302   7.088165   4.245838
# 7 -1.514595   6.447165   3.679172
# 8 -1.391163   4.476218   1.949980
# 9 -1.353190   4.096186   1.613145

# %%
# Create an elbow curve to find the best value for K.

inertia = []

k = list(range(1,11))

for i in k:
    
    km = KMeans(n_clusters=i, random_state=0)
    
    km.fit(pca_df)
    
    inertia.append(km.inertia_)

elbow_data = {"k": k, "inertia": inertia}

df_elbow = pd.DataFrame(elbow_data)
    
# Plot
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %%
# Initialize the K-Means model.
model = KMeans(n_clusters=3, random_state=1)

# Fit the model
model.fit(pca_df)

# Predict clusters
predictions = model.predict(pca_df)

predictions
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
clustered_df = df.join(pca_df, how='inner')

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 


#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
clustered_df['Class'] = predictions

# Print the shape of the clustered_df
print(clustered_df.shape)

clustered_df
# Out:
# (1932, 21)
#       index  Year Ticker                            Company        Sector  \
# 0         0  2021    WMT                       Walmart Inc.  Retail Trade
# 1         1  2020    WMT                       Walmart Inc.  Retail Trade
# 2         2  2019    WMT                       Walmart Inc.  Retail Trade
# 3         3  2018    WMT                       Walmart Inc.  Retail Trade
# 4         4  2021   AMZN                   Amazon.com, Inc.  Retail Trade
# ...     ...   ...    ...                                ...           ...
# 1927   1927  2018    HST                        Host Hotels       Finance
# 1928   1928  2021    PNW  Pinnacle West Capital Corporation     Utilities
# 1929   1929  2020    PNW  Pinnacle West Capital Corporation     Utilities
# 1930   1930  2019    PNW  Pinnacle West Capital Corporation     Utilities
# 1931   1931  2018    PNW  Pinnacle West Capital Corporation     Utilities
#
#       numEmployees     netIncome  netIncome_per_emp   grossProfit  \
# 0        2300000.0  1.367300e+10       5.944783e+03  1.437540e+11
# 1        2070000.0  1.351000e+10       6.526570e+03  1.388360e+11
# 2        1863000.0  1.488100e+10       7.987654e+03  1.293590e+11
# 3        1676700.0  6.670000e+09       3.978052e+03  1.291040e+11
# 4        1298000.0  3.336400e+10       2.570416e+04  1.974780e+11
# ...            ...           ...                ...           ...
# 1927         119.0  1.087000e+09       9.147753e+06  1.601000e+09
# 1928          88.0  6.187200e+08       7.030909e+06  1.697217e+09
# 1929          79.0  5.505590e+08       6.951503e+06  1.634653e+09
# 1930          71.0  5.383200e+08       7.552189e+06  1.487356e+09
# 1931          64.0  5.110470e+08       7.966190e+06  1.578387e+09
#
#       grossProfit_per_emp  ...  operatingIncome_per_emp  totalRevenue  \
# 0            6.250174e+04  ...             1.127913e+04  5.727540e+11
# 1            6.707053e+04  ...             1.301836e+04  5.591510e+11
# 2            6.943586e+04  ...             1.152335e+04  5.239640e+11
# 3            7.699887e+04  ...             1.309537e+04  5.144050e+11
# 4            1.521402e+05  ...             1.916718e+04  4.698220e+11
# ...                   ...  ...                      ...           ...
# 1927         1.347337e+07  ...             6.841879e+06  5.554000e+09
# 1928         1.928656e+07  ...             1.043012e+07  3.803835e+09
# 1929         2.063956e+07  ...             1.066279e+07  3.586982e+09
# 1930         2.086639e+07  ...             9.749565e+06  3.471209e+09
# 1931         2.460386e+07  ...             1.283636e+07  3.691247e+09
#
#       totalRevenue_per_emp  totalOperatingExpenses  \
# 0             2.490235e+05            5.468120e+11
# 1             2.701213e+05            5.322030e+11
# 2             2.812475e+05            5.024960e+11
# 3             3.067961e+05            4.924480e+11
# 4             3.619584e+05            4.449430e+11
# ...                    ...                     ...
# 1927          4.674022e+07            4.741000e+09
# 1928          4.322540e+07            2.885984e+09
# 1929          4.529018e+07            2.742489e+09
# 1930          4.869822e+07            2.776260e+09
# 1931          5.753908e+07            2.867769e+09
#
#       totalOperatingExpenses_per_emp  mostly_remote        PC1        PC2  \
# 0                       2.377443e+05              0  -2.384966  14.666472
# 1                       2.571029e+05              1  -2.230240  13.271748
# 2                       2.697241e+05              0  -2.094849  12.015696
# 3                       2.937007e+05              0  -1.968273  10.885896
# 4                       3.427912e+05              0  -1.668594   8.597475
# ...                              ...            ...        ...        ...
# 1927                    3.989834e+07              0  28.460083   3.940912
# 1928                    3.279527e+07              0  29.534423   3.871850
# 1929                    3.462739e+07              0  30.722066   4.074353
# 1930                    3.894865e+07              0  31.893325   4.344786
# 1931                    4.470272e+07              0  37.697128   5.364074
#
#             PC3  Class
# 0     11.006475      2
# 1      9.759184      2
# 2      8.637236      2
# 3      7.626092      2
# 4      5.572142      2
# ...         ...    ...
# 1927  -2.293452      1
# 1928  -1.508284      1
# 1929  -1.680239      1
# 1930  -2.113859      1
# 1931  -2.584325      1
#
# [1932 rows x 21 columns]

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    clustered_df, 
    x="PC1", 
    y="Year", 
    z="PC2", 
    color="Class", 
    symbol="Class",
    #size="TotalCoinsMined",
    hover_name="Company",
    hover_data=["Year"],
    width=800)

fig.update_layout(legend=dict(x=0,y=1))

fig.show()
# Out:
# <div>                            <div id="6854d2b7-29c0-4d5c-a387-f2a3b399598f" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6854d2b7-29c0-4d5c-a387-f2a3b399598f")) {                    Plotly.newPlot(                        "6854d2b7-29c0-4d5c-a387-f2a3b399598f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Class=%{marker.color}<br>PC1=%{x}<br>Year=%{y}<br>PC2=%{z}<extra></extra>","hovertext":["Walmart Inc.","Walmart Inc.","Walmart Inc.","Walmart Inc.","Amazon.com, Inc.","Amazon.com, Inc.","Amazon.com, Inc.","Amazon.com, Inc.","Accenture plc","Accenture plc","Accenture plc","Accenture plc","United Parcel Service, Inc.","United Parcel Service, Inc.","United Parcel Service, Inc.","United Parcel Service, Inc.","Home Depot, Inc. (The)","Home Depot, Inc. (The)","Home Depot, Inc. (The)","Home Depot, Inc. (The)","Kroger Company (The)","Kroger Company (The)","Kroger Company (The)","Kroger Company (The)","Target Corporation","Target Corporation","Target Corporation","Target Corporation","Starbucks Corporation","Starbucks Corporation","Starbucks Corporation","Starbucks Corporation","International Business Machines Corporation","International Business Machines Corporation","International Business Machines Corporation","International Business Machines Corporation","Lowe\u2019s Companies, Inc.","Lowe\u2019s Companies, Inc.","Lowe\u2019s Companies, Inc.","Lowe\u2019s Companies, Inc.","UnitedHealth Group Incorporated","UnitedHealth Group Incorporated","UnitedHealth Group Incorporated","UnitedHealth Group Incorporated","TJX Companies, Inc. (The)","TJX Companies, Inc. (The)","TJX Companies, Inc. (The)","TJX Companies, Inc. (The)","Walgreens Boots Alliance, Inc.","Walgreens Boots Alliance, Inc.","Walgreens Boots Alliance, Inc.","Walgreens Boots Alliance, Inc.","CVS Health Corporation","CVS Health Corporation","CVS Health Corporation","CVS Health Corporation","PepsiCo, Inc.","PepsiCo, Inc.","PepsiCo, Inc.","PepsiCo, Inc.","Cognizant Technology Solutions Corporation","Cognizant Technology Solutions Corporation","Cognizant Technology Solutions Corporation","Cognizant Technology Solutions Corporation","FedEx Corporation","FedEx Corporation","FedEx Corporation","FedEx Corporation","Costco Wholesale Corporation","Costco Wholesale Corporation","Costco Wholesale Corporation","Costco Wholesale Corporation","HCA Healthcare, Inc.","HCA Healthcare, Inc.","HCA Healthcare, Inc.","HCA Healthcare, Inc.","Wells Fargo & Company","Wells Fargo & Company","Wells Fargo & Company","Wells Fargo & Company","JP Morgan Chase & Co.","JP Morgan Chase & Co.","JP Morgan Chase & Co.","JP Morgan Chase & Co.","AT&T Inc.","AT&T Inc.","AT&T Inc.","AT&T Inc.","Bank of America Corporation","Bank of America Corporation","Bank of America Corporation","Bank of America Corporation","Citigroup, Inc.","Citigroup, Inc.","Citigroup, Inc.","Citigroup, Inc.","McDonald\u2019s Corporation","McDonald\u2019s Corporation","McDonald\u2019s Corporation","McDonald\u2019s Corporation","Dollar Tree, Inc.","Dollar Tree, Inc.","Dollar Tree, Inc.","Dollar Tree, Inc.","Walt Disney Company (The)","Walt Disney Company (The)","Walt Disney Company (The)","Walt Disney Company (The)","Ford Motor Company","Ford Motor Company","Ford Motor Company","Ford Motor Company","Microsoft Corporation","Microsoft Corporation","Microsoft Corporation","Microsoft Corporation","Raytheon Technologies Corporation","Raytheon Technologies Corporation","Raytheon Technologies Corporation","Raytheon Technologies Corporation","General Electric Company","General Electric Company","General Electric Company","General Electric Company","Comcast Corporation","Comcast Corporation","Comcast Corporation","Comcast Corporation","Robert Half International Inc.","Robert Half Internati ...
